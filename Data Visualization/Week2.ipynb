# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
my_data = pd.read_csv('GLB.Ts_dSST.csv')
my_data.head()
# Out:
#                                                                                           Land-Ocean: Global Means
# Year Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec  J-D  D-N  DJF  MAM  JJA                       SON
# 1880 -.17 -.24 -.09 -.15 -.09 -.20 -.17 -.09 -.14 -.23 -.21 -.17 -.16 ***  ***  -.11 -.15                     -.19
# 1881 -.19 -.13 .04  .06  .07  -.18 .01  -.02 -.14 -.21 -.18 -.06 -.08 -.09 -.16 .06  -.06                     -.18
# 1882 .17  .15  .05  -.16 -.14 -.22 -.15 -.06 -.14 -.23 -.16 -.35 -.10 -.08 .09  -.08 -.14                     -.18
# 1883 -.28 -.36 -.12 -.18 -.17 -.06 -.07 -.13 -.21 -.11 -.24 -.11 -.17 -.19 -.33 -.16 -.09                     -.19

# %%
my_data.size
# Out:
# 141

# %%
col_name = my_data.columns.tolist()
col_name
# Out:
# ['Land-Ocean: Global Means']

# %%
mydata2 = pd.read_csv('ExcelFormattedGISTEMPDataCSV.csv')
mydata2.tail(20)
# Out:
#      Year  Jan  Feb  Mar  Apr  May  Jun   Jul   Aug   Sep   Oct   Nov   Dec  \
# 116  1996   27   49   34   36   29   26    35    50    26    21    41    40
# 117  1997   33   37   51   37   38   54    37    42    55    65    65    59
# 118  1998   61   89   62   64   71   77    70    69    46    46    49    58
# 119  1999   48   67   33   34   33   37    41    35    43    42    41    48
# 120  2000   26   59   59   59   40   43    42    43    43    29    33    30
# 121  2001   45   47   58   52   59   54    60    50    56    52    71    55
# 122  2002   74   76   91   59   65   55    61    55    64    57    59    42
# 123  2003   72   55   57   55   63   48    55    66    67    75    55    74
# 124  2004   58   70   66   62   42   42    27    45    53    67    72    52
# 125  2005   72   59   69   70   64   66    66    63    77    80    75    68
# 126  2006   57   71   64   49   47   64    55    71    64    70    73    78
# ...

# %%
col_name = mydata2.columns.tolist()

# %%
mydata3 = pd.read_csv('ExcelFormattedGISTEMPData2CSV.csv')
mydata3.tail()
# Out:
#      Year  Glob  NHem  SHem  24N-90N  24S-24N  90S-24S  64N-90N  44N-64N  \
# 130  2010    71    88    55       98       69       48      199       86
# 131  2011    60    71    50       93       37       58      211       90
# 132  2012    63    77    50       97       51       44      189       89
# 133  2013    66    76    56       88       58       54      123      103
# 134  2014    75    91    58      106       67       54      185      113
#
#      24N-44N  EQU-24N  24S-EQU  44S-24S  64S-44S  90S-64S
# 130       74       72       66       66       23       38
# 131       57       38       37       68       26       93
# 132       73       46       57       60       25       32
# 133       68       57       58       64       30       67
# 134       76       70       64       76       23       47

# %%
mydata3.head()
# Out:
#    Year  Glob  NHem  SHem  24N-90N  24S-24N  90S-24S  64N-90N  44N-64N  \
# 0  1880   -19   -33    -5      -38      -16       -5      -89      -54
# 1  1881   -10   -18    -2      -27       -2       -5      -54      -40
# 2  1882    -9   -17    -1      -21      -10        4     -125      -20
# 3  1883   -19   -30    -8      -34      -22       -2      -28      -57
# 4  1884   -27   -42   -12      -56      -17      -11     -127      -58
#
#    24N-44N  EQU-24N  24S-EQU  44S-24S  64S-44S  90S-64S
# 0      -22      -26       -5       -2       -8       39
# 1      -14       -5        2       -6       -3       37
# 2       -3      -12       -8        3        8       42
# 3      -20      -25      -19       -1        0       37
# 4      -41      -21      -14      -15       -5       40

# %%
nhem = mydata3[['Year','Glob','SHem','NHem']]
nhem.head()
# Out:
#    Year  Glob  SHem  NHem
# 0  1880   -19    -5   -33
# 1  1881   -10    -2   -18
# 2  1882    -9    -1   -17
# 3  1883   -19    -8   -30
# 4  1884   -27   -12   -42

# %%
plt.plot(nhem['Year'],nhem['NHem'])
plt.plot(nhem['Year'],nhem['SHem'])

# %%
fig = plt.figure()
ax = plt.subplot(111)
ax.plot(nhem['Year'],nhem['NHem'], label='North Hem temperature')
ax.plot(nhem['Year'],nhem['SHem'], label='South Hem temperature')
#ax.plot(nhem['Year'],nhem['Glob'], label='Global temperature')
plt.title('Temperature of South Hem, North Hem and global from 1880-2019')
plt.xlabel('Year')
plt.ylabel('Temperature in F')
ax.legend()
plt.show()

# %%
# find out which year the South Hem is cooler than North Hem
south_cooler = nhem[nhem['SHem'] < nhem['NHem']]
south_cooler.size
# Out:
# 296

# %%
# from 1885, compare the global temperature differ from 5 years ago
row_count,cc = nhem.shape
temp_diff = np.array(nhem['Glob'])
gap = 5
t1 = np.copy(temp_diff[gap:])
t2 = np.copy(temp_diff[0:(row_count-gap)])
t1.size
t2.size
tdiff = t1-t2
print(t1)
print(t2)
print(tdiff)
# Out:
# [-31 -30 -33 -20 -11 -36 -23 -26 -29 -30 -21 -14 -11 -28 -16  -8 -13 -26
#  -35 -44 -27 -21 -39 -42 -47 -42 -44 -35 -33 -15 -10 -33 -39 -24 -21 -25
#  -19 -26 -22 -26 -19  -8 -20 -20 -35 -13  -9 -16 -28 -13 -19 -14  -1  -2
#   -3   8  13  10  14  26  13  -3  -3  -9  -9 -18  -7   1   8 -12 -14 -20
#    3   6   3  -3   5   3   6 -20 -10  -5  -2  -7   6   3  -9   1  15  -8
#   -1 -11  18   7  17  28  33  13  31  16  12  19  34  40  29  44  42  23
#   24  32  46  35  48  63  42  42  55  63  62  55  69  64  66  54  65  71
#   60  63  66  75]
# [-19 -10  -9 -19 -27 -31 -30 -33 -20 -11 -36 -23 -26 -29 -30 -21 -14 -11
#  -28 -16  -8 -13 -26 -35 -44 -27 -21 -39 -42 -47 -42 -44 -35 -33 -15 -10
#  -33 -39 -24 -21 -25 -19 -26 -22 -26 -19  -8 -20 -20 -35 -13  -9 -16 -28
#  -13 -19 -14  -1  -2  -3   8  13  10  14  26  13  -3  -3  -9  -9 -18  -7
#    1   8 -12 -14 -20   3   6   3  -3   5   3   6 -20 -10  -5  -2  -7   6
#    3  -9   1  15  -8  -1 -11  18   7  17  28  33  13  31  16  12  19  34
# ...

# %%
nhem.tail(10)
# Out:
#      Year  Glob  SHem  NHem
# 125  2005    69    55    84
# 126  2006    64    47    80
# 127  2007    66    49    83
# 128  2008    54    42    66
# 129  2009    65    59    71
# 130  2010    71    55    88
# 131  2011    60    50    71
# 132  2012    63    50    77
# 133  2013    66    56    76
# 134  2014    75    58    91
